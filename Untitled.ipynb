# %% [markdown]
# # Setup

# %% [markdown]
# ##  Editor de texto

# %% [markdown]
# Durante el estudio utilizare:

# %% [markdown]
# <b>VS Code</b> (Ide liviano)<br>
# **Jupyer notebook / lab**

# %% [markdown]
# Alternativas:

# %% [markdown]
# <ul>
# <li></l**Sublime text 3**, creado por python
# **PyCharm**, ide pesado
# **vim**, muy dificil!

# %% [markdown]
# ## Terminal

# %% [markdown]
# Estaremos utilizando zsh como shell con ohmyzsh como default terminal (mac)
