# %% [markdown]
# # Setup

# %% [markdown]
# ##  Editor de texto

# %% [markdown]
# Durante el estudio utilizare:

# %% [markdown]
# <b>VS Code</b> (Ide liviano)<br>
# **Jupyer notebook / lab**

# %% [markdown]
# Alternativas:

# %% [markdown]
# **Sublime text 3**, creado por python<br>
# **PyCharm**, ide pesado<br>
# **vim**, muy dificil!

# %% [markdown]
# ## Terminal

# %% [markdown]
# Estaremos utilizando zsh como shell con ohmyzsh como default terminal (mac)

# %% [markdown]
# <img src='image/Terminal.png'>

# %% [markdown]
# ### Sobreviviendo en la terminal

# %% [markdown]
# **pwd**<br>
# ls -l<br>
# mkdir (Directorio)<br>
# **cd** (path)<br>
# touch (Archivo)<br>
# rm (archivo)<br>
# mv (desde) (hacia)<br>

# %% [markdown]
# ### Variable PATH

# %% [markdown]
# Un conjunto de directorios donde se encuentran los programas ejecutables

# %% [markdown]
# echo <b>$PATH</b>

# %% [markdown]
# echo <b>$PATH | tr : \\n</b>

# %% [markdown]
# El ~/.zshrc <font color='blue'>file</font> es donde la magia comienza.

# %% [markdown]
# Como solucionar un error de comando no encontrado:

# %% [markdown]
# <font color = 'green'> type </font> -a python

# %% [markdown]
# ## Python
